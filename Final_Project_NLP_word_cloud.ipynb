# %% [markdown]
# ##### import wordcloud as wc

# %%
import pandas as pd

# %%
data = pd.read_csv('/Users/camillebustalinio/Desktop/Camille/term 2 project/airbnb data/final_data.csv')

# %%
exp_comments = data[(data.language=='en')&(data.price_tag=='exp')].comments
exp_words = ' '.join(exp_comments)

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
expensive_cloud = wc.WordCloud(background_color="white",max_font_size=60, relative_scaling=.8).generate(exp_words)
plt.figure(figsize=(12,15))
plt.imshow(expensive_cloud)
plt.title('Expensive listings')
plt.axis("off")
plt.show()

# %%
cheap_comments = data[(data.language=='en')&(data.price_tag=='cheap')].comments
cheap_words = ' '.join(cheap_comments)
cheap_cloud = wc.WordCloud(background_color="white",max_font_size=60, relative_scaling=.8).generate(cheap_words)
plt.figure(figsize=(12,15))
plt.imshow(cheap_cloud)
plt.title('Cheap listings')
plt.axis("off")
plt.show()

# %%
cheap_comments, exp_comments
# Out:
# (30        Very clean, great location, well equipped kitc...
#  31        I met very nice lady that advised me instead o...
#  32        Everything as expected. Functional, clean, nic...
#  33        This one-bedroom apartment is immaculate, comf...
#  34        I stayed at LayKoons Apartment for a week and ...
#  35        The apartment is clean and spacious and has a ...
#  36        We really enjoyed our stay in this lovely and ...
#  37        The apartment was beautiful and well-kept. The...
#  38        LayKoon was a wonderful and welcoming host and...
#  39        Laykoon was the best host ever. She made me fe...
#  40        I cannot say enough wonderful things about my ...
#  41        Cozy and comfortable apartment!  LayKoon is a ...
#  42        A nice, quaint apartment in a quiet neighborho...
#  43        LayKoon was awesome!  Great hospitality and ga...
#  44        My family and I had a very pleasant stay. LayK...
# ...
